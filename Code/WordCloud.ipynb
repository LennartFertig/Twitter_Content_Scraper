# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import word_tokenize
import matplotlib.pyplot as plt
# %matplotlib inline
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Moritz
# [nltk_data]     Mueller\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Moritz
# [nltk_data]     Mueller\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_pickle(r"C:\Users\Moritz Mueller\Downloads\elonmusk_last_100.pkl")
stringOfWords = df['text'].str.cat()

# %%
textTokens = word_tokenize(stringOfWords)
tokens_without_sw = [word for word in textTokens if not word in stopwords.words()]

# %%
tokens_without_sw
# Out:
# ['Even',
#  'applied',
#  '2',
#  'urslf',
#  '@',
#  'garyblack00',
#  'Or',
#  '14',
#  'times',
#  'higher',
#  'Twitter',
#  '’',
#  '5',
#  '%',
#  'case',
#  '🤨',
#  '@',
#  'garyblack00',
#  'So',
#  '…',
#  '[',
#  'checks',
#  'calculator',
#  ']',
#  '…',
#  'would',
#  'like',
#  '10',
#  'times',
#  '5',
#  '%',
#  '@',
#  'garyblack00',
#  'Interesting',
#  '@',
#  'business',
#  'https',
#  ':',
#  '//t.co/qup2NUiOM1bullsh',
#  '*',
#  'baffles',
#  'brains',
#  '@',
#  'heydave7',
#  'Yes',
#  '@',
#  'MmeAlexandraS',
#  '@',
#  'MoodysInvSvc',
#  '@',
#  'SPGlobalRatings',
#  '@',
#  'ICannot_Enough',
#  '@',
#  'RonMadison11',
#  '@',
#  'garyblack00',
#  'Tesla',
#  '’',
#  'need',
#  'debt',
#  ',',
#  'rating',
#  '’',
#  'impact',
#  'us',
#  ',',
#  'silly',
#  '@',
#  'bennyjohnson',
#  'Twitter',
#  'exec',
#  'trashing',
#  'free',
#  'speech',
#  '&',
#  'amp',
#  ';',
#  'mocking',
#  'people',
#  'Asperger',
#  '’',
#  '…',
#  '@',
#  'bennyjohnson',
#  '@',
#  'Twitter',
#  '😔',
#  '@',
#  'intelligent_eat',
#  'Yes',
#  ',',
#  'purpose',
#  'AI',
#  'Day',
#  'convince',
#  'great',
#  'AI/software/chip',
#  'talent',
#  'join',
#  'TeslaTesla',
#  'AI',
#  'Day',
#  '#',
#  '2',
#  'Aug',
#  '19',
#  '.',
#  'So',
#  'many',
#  'cool',
#  'updates',
#  '!',
#  '@',
#  'bennyjohnson',
#  'Is',
#  'legit',
#  '?',
#  '@',
#  'EvaFoxU',
#  'Hello',
#  '@',
#  'SECGov',
#  ',',
#  'anyone',
#  'home',
#  '?',
#  'Twitter',
#  'claims',
#  '&',
#  'gt',
#  ';',
#  '95',
#  '%',
#  'daily',
#  'active',
#  'users',
#  'real',
#  ',',
#  'unique',
#  'humans',
#  '.',
#  'Does',
#  'anyone',
#  'experience',
#  '?',
#  '@',
#  'cb_doge',
#  'The',
#  'audience',
#  'laughter',
#  'says',
#  '@',
#  'johnrich',
#  'Absolutely',
#  '@',
#  'PPathole',
#  '@',
#  'Teslarati',
#  'Exactly',
#  '@',
#  'occupymars42069',
#  '@',
#  'paraga',
#  'Interesting',
#  '@',
#  'Andst7',
#  '@',
#  'paraga',
#  'Seems',
#  'like',
#  'Twitter',
#  'welcome',
#  'external',
#  'validation',
#  'claims',
#  'true',
#  '@',
#  'Teslarati',
#  '20',
#  '%',
#  'fake/spam',
#  'accounts',
#  ',',
#  '4',
#  'times',
#  'Twitter',
#  'claims',
#  ',',
#  'could',
#  '*',
#  'much',
#  '*',
#  'higher',
#  '.',
#  'My',
#  'offer',
#  'based',
#  'Twitter',
#  '’',
#  'SEC',
#  'filings',
#  'accurate',
#  '.',
#  'Yesterday',
#  ',',
#  'Twitter',
#  '’',
#  'CEO',
#  'publicly',
#  'refused',
#  'show',
#  'proof',
#  '&',
#  'lt',
#  ';',
#  '5',
#  '%',
#  '.',
#  'This',
#  'deal',
#  'move',
#  'forward',
#  '.',
#  '@',
#  'paul_griffiths',
#  'This',
#  'transcription',
#  '’',
#  'precise',
#  ',',
#  'gets',
#  'gist',
#  '@',
#  'BillyM2k',
#  '🤣',
#  '@',
#  'BillyM2k',
#  '@',
#  'jarokrolewski',
#  '💯',
#  '@',
#  'jarokrolewski',
#  'Just',
#  'scratch',
#  'really',
#  '@',
#  'slashdot',
#  '!',
#  '@',
#  'S0meW0rri3s',
#  '@',
#  'BillyM2k',
#  '@',
#  'paraga',
#  '@',
#  'Dilbert_Daily',
#  '🤣',
#  '@',
#  'Andst7',
#  '@',
#  'paraga',
#  '👍',
#  '@',
#  'paraga',
#  'So',
#  'advertisers',
#  'know',
#  '’',
#  'getting',
#  'money',
#  '?',
#  'This',
#  'fundamental',
#  'financial',
#  'health',
#  'Twitter',
#  '.',
#  '@',
#  'paraga',
#  '💩',
#  '@',
#  'paraga',
#  'Have',
#  'tried',
#  'calling',
#  '?',
#  '@',
#  'BillyM2k',
#  'Billy',
#  'best',
#  '@',
#  'alanagoodman',
#  'I',
#  'wonder',
#  'funds',
#  '@',
#  'SPKolten',
#  '@',
#  'heyitsyashu',
#  'I',
#  '’',
#  'much',
#  'choice',
#  '.',
#  'Provided',
#  '’',
#  'explicitly',
#  'say',
#  'I',
#  'endorse',
#  'something',
#  ',',
#  'legal',
#  'recourse',
#  '.',
#  '@',
#  'jokowi',
#  'It',
#  'honor',
#  'meet',
#  'Starbase',
#  'discuss',
#  'exciting',
#  'future',
#  'projects',
#  '!',
#  '@',
#  'heyitsyashu',
#  'I',
#  'hope',
#  '’',
#  'good',
#  'product',
#  '!',
#  '@',
#  'historydefined',
#  'Tragically',
#  ',',
#  '’',
#  'even',
#  'oil',
#  'snake',
#  '!',
#  '@',
#  'verge',
#  '🔥',
#  '@',
#  'TomFitton',
#  '@',
#  'netflix',
#  '@',
#  'Twitter',
#  '@',
#  'WSJ',
#  'Good',
#  'move',
#  '@',
#  'netflix',
#  '@',
#  'teslaownersSV',
#  'No',
#  ',',
#  'I',
#  'interact',
#  'interesting',
#  'comments',
#  'I',
#  'see',
#  ',',
#  'even',
#  'made',
#  'people',
#  'I',
#  '’',
#  'follow',
#  '@',
#  'BillyM2k',
#  'I',
#  '’',
#  'bot',
#  '&',
#  'amp',
#  ';',
#  '’',
#  'wife',
#  '@',
#  'ZacksJerryRig',
#  'Wow',
#  ',',
#  'must',
#  'Sherlock',
#  'f',
#  '*',
#  'Holmes',
#  '.',
#  'I',
#  '’',
#  'joking',
#  '.',
#  '@',
#  'reckless',
#  'Tried',
#  'TikTok',
#  ',',
#  '’',
#  'winding',
#  '⏰Not',
#  'mention',
#  'potential',
#  'bugs',
#  'code',
#  '.',
#  'Open',
#  'source',
#  'way',
#  'go',
#  'solve',
#  'trust',
#  'efficacy.I',
#  '’',
#  'suggesting',
#  'malice',
#  'algorithm',
#  ',',
#  'rather',
#  '’',
#  'trying',
#  'guess',
#  'might',
#  'read',
#  ',',
#  ',',
#  'inadvertently',
#  'manipulate/amplify',
#  'viewpoints',
#  'without',
#  'realizing',
#  'happening',
#  '@',
#  'StrivenB',
#  '@',
#  'BLKMDL3',
#  '@',
#  'PPathole',
#  'That',
#  '’',
#  'deep',
#  'cut',
#  '(',
#  'sigh',
#  ')',
#  '@',
#  'MODL3PILOT',
#  '@',
#  'coffeetabletsla',
#  '@',
#  'PPathole',
#  '@',
#  'Twitter',
#  'Yes',
#  ',',
#  'would',
#  'big',
#  'impact',
#  '!',
#  '@',
#  'coffeetabletsla',
#  '@',
#  'PPathole',
#  '@',
#  'Twitter',
#  'With',
#  'usernames',
#  'like',
#  ',',
#  'bots',
#  '’',
#  'even',
#  'trying',
#  'hard',
#  '!',
#  '@',
#  'BLKMDL3',
#  '@',
#  'PPathole',
#  'There',
#  'chance',
#  'might',
#  '90',
#  '%',
#  'daily',
#  'active',
#  'users',
#  ',',
#  'metric',
#  'matters',
#  'advertisers',
#  '.',
#  'Very',
#  'odd',
#  'popular',
#  'tweets',
#  'time',
#  'liked',
#  '~2',
#  '%',
#  'daily',
#  'active',
#  'users',
#  '.',
#  '@',
#  'PPathole',
#  'Exactly',
#  '.',
#  'I',
#  'yet',
#  'see',
#  '*',
#  '*',
#  'analysis',
#  'fake/spam/duplicates',
#  '&',
#  'lt',
#  ';',
#  '5',
#  '%',
#  '.',
#  '@',
#  'mtaibbi',
#  'Shame',
#  '@',
#  'WSJ',
#  'shoddy',
#  'reporting',
#  '!',
#  '@',
#  'SnoopDogg',
#  '🔥🔥Iconic',
#  'laconic',
#  '!',
#  'platonicIncredible',
#  'artGreat',
#  'shoesBorderline',
#  'sexy',
#  'https',
#  ':',
#  '//t.co/2ShbhQKilzSooo',
#  'tasty',
#  'first',
#  ',',
#  'golden',
#  'eggs',
#  '…The',
#  'Golden',
#  'State',
#  'cooking',
#  'golden',
#  'geese',
#  '@',
#  'mtaibbi',
#  '🧐',
#  '@',
#  'F9Block5',
#  'YesThe',
#  'Lawyers',
#  'Who',
#  'Ate',
#  'California',
#  'https',
#  ':',
#  '//t.co/i4PCxc5RBH',
#  '@',
#  'nichegamer',
#  'Just',
#  'another',
#  'day',
#  'Elden',
#  'Ring',
#  '!',
#  '@',
#  'PPathole',
#  '@',
#  'Twitter',
#  'Twitter',
#  'legal',
#  'called',
#  'complain',
#  'I',
#  'violated',
#  'NDA',
#  'revealing',
#  'bot',
#  'check',
#  'sample',
#  'size',
#  '100',
#  '!',
#  'This',
#  'actually',
#  'happened',
#  '.',
#  '(',
#  'This',
#  'message',
#  'brought',
#  'Illuminaughty',
#  ')',
#  'Very',
#  'important',
#  'fix',
#  'Twitter',
#  'feed',
#  ':',
#  '1',
#  '.',
#  'Tap',
#  'home',
#  'button',
#  '.',
#  '2',
#  '.',
#  'Tap',
#  'stars',
#  'upper',
#  'right',
#  'screen',
#  '.',
#  '3',
#  '.',
#  'Select',
#  '“',
#  'Latest',
#  'tweets',
#  '”',
#  '.',
#  'You',
#  'manipulated',
#  'algorithm',
#  'ways',
#  '’',
#  'realize',
#  '.',
#  'Easy',
#  'switch',
#  'back',
#  '&',
#  'amp',
#  ';',
#  'forth',
#  'see',
#  'difference',
#  '.',
#  '@',
#  'TimRunsHisMouth',
#  '🤣🎯',
#  '@',
#  'DBurkland',
#  'Team',
#  'working',
#  'weekend',
#  'get',
#  '10.12',
#  'limited',
#  'release',
#  'tomorrow',
#  '.',
#  'Then',
#  'evaluate',
#  ',',
#  'point',
#  'update',
#  ',',
#  'broaden',
#  'release',
#  '.',
#  '10.12.2',
#  'probably',
#  'expand',
#  'safety',
#  'score',
#  '95+.At',
#  'least',
#  ',',
#  '’',
#  'lib',
#  'hivemind',
#  'thinks',
#  'hahaWhoever',
#  'thought',
#  'owning',
#  'libs',
#  'would',
#  'cheap',
#  'never',
#  'tried',
#  'acquire',
#  'social',
#  'media',
#  'company',
#  '!',
#  'The',
#  'bots',
#  'angry',
#  'counted',
#  '🤣',
#  '@',
#  'PPathole',
#  '@',
#  'Twitter',
#  'Any',
#  'sensible',
#  'random',
#  'sampling',
#  'process',
#  'fine',
#  '.',
#  'If',
#  'many',
#  'people',
#  'independently',
#  'get',
#  'similar',
#  'results',
#  '%',
#  'fake/spam/duplicate',
#  'accounts',
#  ',',
#  'telling',
#  '.',
#  'I',
#  'picked',
#  '100',
#  'sample',
#  'size',
#  'number',
#  ',',
#  'Twitter',
#  'uses',
#  'calculate',
#  '&',
#  'lt',
#  ';',
#  '5',
#  '%',
#  'fake/spam/duplicate',
#  '.',
#  '@',
#  'fintwit_news',
#  '@',
#  'Twitter',
#  'I',
#  'relied',
#  'upon',
#  'accuracy',
#  'Twitter',
#  '’',
#  'public',
#  'filings',
#  '@',
#  'stevenmarkryan',
#  '@',
#  'teslaownersSV',
#  '@',
#  'Twitter',
#  'Interesting',
#  '@',
#  'teslaownersSV',
#  '@',
#  'Twitter',
#  'If',
#  'collectively',
#  'try',
#  'figure',
#  'bot/duplicate',
#  'user',
#  'percentage',
#  ',',
#  'probably',
#  'crowdsource',
#  'good',
#  'answer',
#  '@',
#  'teslaownersSV',
#  '@',
#  'Twitter',
#  'Ignore',
#  'first',
#  '1000',
#  'followers',
#  ',',
#  'pick',
#  'every',
#  '10th',
#  '.',
#  'I',
#  '’',
#  'open',
#  'better',
#  'ideas',
#  '.',
#  '@',
#  'coffeetabletsla',
#  '@',
#  'Twitter',
#  'Pick',
#  'account',
#  'lot',
#  'followersTo',
#  'find',
#  ',',
#  'team',
#  'random',
#  'sample',
#  '100',
#  'followers',
#  '@',
#  'twitter',
#  '.',
#  'I',
#  'invite',
#  'others',
#  'repeat',
#  'process',
#  'see',
#  'discover',
#  '…',
#  '@',
#  'BillyM2k',
#  'The',
#  'axiomatic',
#  'error',
#  'housing',
#  'prices',
#  'go',
#  '.',
#  'I',
#  '’',
#  'support',
#  'predatory',
#  'lending',
#  ',',
#  'many',
#  'lenders',
#  'severely',
#  'wounded',
#  '’',
#  'survive',
#  '.',
#  'They',
#  'dug',
#  'graves',
#  '–',
#  'lesson',
#  'heart',
#  ',',
#  'including',
#  'me.Still',
#  'committed',
#  'acquisitionTwitter',
#  'deal',
#  'temporarily',
#  'hold',
#  'pending',
#  'details',
#  'supporting',
#  'calculation',
#  'spam/fake',
#  'accounts',
#  'indeed',
#  'represent',
#  'less',
#  '5',
#  '%',
#  'users',
#  'https',
#  ':',
#  '//t.co/Y2t0QMuuynThe',
#  'straw',
#  'emblematic',
#  'larger',
#  'social',
#  'issues',
#  '@',
#  'Gfilche',
#  '@',
#  'Tesla',
#  'It',
#  'still',
#  'needs',
#  'work',
#  'imo',
#  ',',
#  'probably',
#  'widen',
#  'beta',
#  'little',
#  'next',
#  'month',
#  '@',
#  'pmarca',
#  'This',
#  'messed',
#  '@',
#  'JeffTutorials',
#  'Seriously',
#  '?',
#  'How',
#  'even',
#  'start',
#  '?',
#  '@',
#  'PPathole',
#  '💯',
#  '@',
#  'teslaownersSV',
#  'And',
#  'tastes',
#  'like',
#  'cardboard',
#  '!',
#  'The',
#  'last',
#  'straw',
#  'last',
#  'straw',
#  '!',
#  'Stop',
#  'straws',
#  '!',
#  'https',
#  ':',
#  '//t.co/aHv7uvm17D',
#  '@',
#  'ScottAdamsSays',
#  '@',
#  'DawgGabriel',
#  'But',
#  'I',
#  'think',
#  'twitter',
#  'authenticate',
#  'real',
#  'users',
#  'prioritize',
#  'replies',
#  'unauthenticated',
#  'users',
#  '@',
#  'ScottAdamsSays',
#  '@',
#  'DawgGabriel',
#  'The',
#  'drinking',
#  'bleach',
#  'hoax',
#  'hoax',
#  'https',
#  ':',
#  '//t.co/bORNLRfzSXUpdated',
#  'Starlink',
#  'availability',
#  'region',
#  'https',
#  ':',
#  '//t.co/uxLqoNpr7M',
#  '@',
#  'BillyM2k',
#  'If',
#  'Twitter',
#  'tell',
#  'difference',
#  'real',
#  'fake',
#  'users',
#  ',',
#  'allow',
#  'comments',
#  '?',
#  'https',
#  ':',
#  '//t.co/0EuhTfaVfF',
#  '@',
#  'lexfridman',
#  'Exactly',
#  '@',
#  'PPathole',
#  '@',
#  'BillyM2k',
#  'Didn',
#  '’',
#  'occur',
#  'founders',
#  'USA',
#  'people',
#  'would',
#  'live',
#  'long',
#  ',',
#  'put',
#  ...]

# %%
word_cloud = WordCloud(collocations = True, background_color = 'white').generate((" ").join(tokens_without_sw))

# Display the generated Word Cloud

plt.imshow(word_cloud, interpolation='bilinear')

plt.axis("off")

plt.show()
